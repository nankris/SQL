# %%
import os

# %%
#!pip install mysql-connector

# %%
#!pip uninstall mysql-connector

# %%
#!pip install mysql-connector-python

# %%
import mysql.connector

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
user_name=os.environ.get('DB_USER')
password=os.environ.get('DB_PASS')

# %%
connection=mysql.connector.connect(host='localhost', user="root",password="harinhk",database='imdb',auth_plugin='mysql_native_password')

# %%
connection

# %%
#DML means data manipulation language #insert, update and delete are DML commands

# %%
#DDL commands
#Create, alter, drop, truncate ,rename, truncate, rename

# %%
pd.read_sql_query("CREATE TABLE student(sno int, sname varchar(20), age int, dob date)", connection)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-db736b81574e> in <module>()
# ----> 1 pd.read_sql_query("CREATE TABLE student(sno int, sname varchar(20), age int, dob date)", connection)
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# --> 332         chunksize=chunksize,
#     333     )
#     334
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1644         args = _convert_params(sql, params)
#    1645         cursor = self.execute(*args)
# -> 1646         columns = [col_desc[0] for col_desc in cursor.description]
#    1647
#    1648         if chunksize is not None:
#
# TypeError: 'NoneType' object is not iterable

# %%
pd.read_sql_query("SHOW TABLES FROM imdb", connection)
# Out:
#      Tables_in_imdb
# 0            actors
# 1         directors
# 2  directors_genres
# 3          estudent
# 4        helloworld
# 5            movies
# 6  movies_directors
# 7     movies_genres
# 8             roles
# 9           student

# %%
pd.read_sql_query("SELECT * FROM student", connection)
# Out:
# Empty DataFrame
# Columns: [sno, sname, age, dob]
# Index: []

# %%
pd.read_sql_query("INSERT INTO student values(1,'nhk',24,curdate())", connection)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-ec8f004d0c4b> in <module>()
# ----> 1 pd.read_sql_query("INSERT INTO student values(1,'nhk',24,curdate())", connection)
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# --> 332         chunksize=chunksize,
#     333     )
#     334
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1644         args = _convert_params(sql, params)
#    1645         cursor = self.execute(*args)
# -> 1646         columns = [col_desc[0] for col_desc in cursor.description]
#    1647
#    1648         if chunksize is not None:
#
# TypeError: 'NoneType' object is not iterable

# %%
pd.read_sql_query("SELECT * FROM student", connection)
# Out:
#    sno sname  age         dob
# 0    1   nhk   24  2020-05-19

# %%
#dropping the table
pd.read_sql_query("DROP TABLE student", connection)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-513ca3df157e> in <module>()
#       1 #dropping the table
# ----> 2 pd.read_sql_query("DROP TABLE student", connection)
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# --> 332         chunksize=chunksize,
#     333     )
#     334
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1644         args = _convert_params(sql, params)
#    1645         cursor = self.execute(*args)
# -> 1646         columns = [col_desc[0] for col_desc in cursor.description]
#    1647
#    1648         if chunksize is not None:
#
# TypeError: 'NoneType' object is not iterable

# %%
pd.read_sql_query("SELECT * FROM student", connection)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1594             else:
# -> 1595                 cur.execute(*args)
#    1596             return cur
#
# ~\Anaconda3\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     568         try:
# --> 569             self._handle_result(self._connection.cmd_query(stmt))
#     570         except errors.InterfaceError:
#
# ~\Anaconda3\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     597             query = query.encode('utf-8')
# --> 598         result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     599
#
# ~\Anaconda3\lib\site-packages\mysql\connector\connection.py in _handle_result(self, packet)
#     485         elif packet[4] == 255:
# --> 486             raise errors.get_exception(packet)
#     487
#
# ProgrammingError: 1146 (42S02): Table 'imdb.student' doesn't exist
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-18-907f6fe79746> in <module>()
# ----> 1 pd.read_sql_query("SELECT * FROM student", connection)
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# --> 332         chunksize=chunksize,
#     333     )
#     334
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1643
#    1644         args = _convert_params(sql, params)
# -> 1645         cursor = self.execute(*args)
#    1646         columns = [col_desc[0] for col_desc in cursor.description]
#    1647
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1608                 "Execution failed on sql '{sql}': {exc}".format(sql=args[0], exc=exc)
#    1609             )
# -> 1610             raise_with_traceback(ex)
#    1611
#    1612     @staticmethod
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\compat\__init__.py in raise_with_traceback(exc, traceback)
#      45     if traceback == Ellipsis:
#      46         _, _, traceback = sys.exc_info()
# ---> 47     raise exc.with_traceback(traceback)
#      48
#      49
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1593                 cur.execute(*args, **kwargs)
#    1594             else:
# -> 1595                 cur.execute(*args)
#    1596             return cur
#    1597         except Exception as exc:
#
# ~\Anaconda3\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     567
#     568         try:
# --> 569             self._handle_result(self._connection.cmd_query(stmt))
#     570         except errors.InterfaceError:
#     571             if self._connection._have_next_result:  # pylint: disable=W0212
#
# ~\Anaconda3\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     596         if not isinstance(query, bytes):
#     597             query = query.encode('utf-8')
# --> 598         result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     599
#     600         if self._have_next_result:
#
# ~\Anaconda3\lib\site-packages\mysql\connector\connection.py in _handle_result(self, packet)
#     484             return self._handle_eof(packet)
#     485         elif packet[4] == 255:
# --> 486             raise errors.get_exception(packet)
#     487
#     488         # We have a text result set
#
# DatabaseError: Execution failed on sql 'SELECT * FROM student': 1146 (42S02): Table 'imdb.student' doesn't exist

# %%
pd.read_sql_query("CREATE TABLE student(sno int, sname varchar(20), age int, dob date)", connection)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-db736b81574e> in <module>()
# ----> 1 pd.read_sql_query("CREATE TABLE student(sno int, sname varchar(20), age int, dob date)", connection)
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# --> 332         chunksize=chunksize,
#     333     )
#     334
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1644         args = _convert_params(sql, params)
#    1645         cursor = self.execute(*args)
# -> 1646         columns = [col_desc[0] for col_desc in cursor.description]
#    1647
#    1648         if chunksize is not None:
#
# TypeError: 'NoneType' object is not iterable

# %%
pd.read_sql_query("SELECT * FROM student", connection)
# Out:
# Empty DataFrame
# Columns: [sno, sname, age, dob]
# Index: []

# %%
pd.read_sql_query("DESC student", connection)
# Out:
#    Field         Type Null Key Default Extra
# 0    sno      int(11)  YES        None
# 1  sname  varchar(20)  YES        None
# 2    age      int(11)  YES        None
# 3    dob         date  YES        None

# %%
#ALTER 
pd.read_sql_query("ALTER TABLE student add marks int", connection)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-7793d4fb2c85> in <module>()
#       1 #ALTER
# ----> 2 pd.read_sql_query("ALTER TABLE student add marks int", connection)
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# --> 332         chunksize=chunksize,
#     333     )
#     334
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1644         args = _convert_params(sql, params)
#    1645         cursor = self.execute(*args)
# -> 1646         columns = [col_desc[0] for col_desc in cursor.description]
#    1647
#    1648         if chunksize is not None:
#
# TypeError: 'NoneType' object is not iterable

# %%
pd.read_sql_query("DESC student", connection)
# Out:
#    Field         Type Null Key Default Extra
# 0    sno      int(11)  YES        None
# 1  sname  varchar(20)  YES        None
# 2    age      int(11)  YES        None
# 3    dob         date  YES        None
# 4  marks      int(11)  YES        None

# %%
#dropping a column
pd.read_sql_query("ALTER TABLE student DROP dob", connection)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-fc86648fd48c> in <module>()
#       1 #dropping a column
# ----> 2 pd.read_sql_query("ALTER TABLE student DROP dob", connection)
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# --> 332         chunksize=chunksize,
#     333     )
#     334
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1644         args = _convert_params(sql, params)
#    1645         cursor = self.execute(*args)
# -> 1646         columns = [col_desc[0] for col_desc in cursor.description]
#    1647
#    1648         if chunksize is not None:
#
# TypeError: 'NoneType' object is not iterable

# %%
pd.read_sql_query("DESC student", connection)
# Out:
#    Field         Type Null Key Default Extra
# 0    sno      int(11)  YES        None
# 1  sname  varchar(20)  YES        None
# 2    age      int(11)  YES        None
# 3  marks      int(11)  YES        None

# %%
pd.read_sql_query("ALTER TABLE student ADD subject INT", connection)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-58adeed979ee> in <module>()
# ----> 1 pd.read_sql_query("ALTER TABLE student ADD subject INT", connection)
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# --> 332         chunksize=chunksize,
#     333     )
#     334
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1644         args = _convert_params(sql, params)
#    1645         cursor = self.execute(*args)
# -> 1646         columns = [col_desc[0] for col_desc in cursor.description]
#    1647
#    1648         if chunksize is not None:
#
# TypeError: 'NoneType' object is not iterable

# %%
pd.read_sql_query("DESC student", connection)
# Out:
#      Field         Type Null Key Default Extra
# 0      sno      int(11)  YES        None
# 1    sname  varchar(20)  YES        None
# 2      age      int(11)  YES        None
# 3    marks      int(11)  YES        None
# 4  subject      int(11)  YES        None

# %%
pd.read_sql_query("INSERT INTO student values(2, 'nhk2',25,98,'maths')", connection)
#pd.read_sql_query("INSERT INTO student values(1,'nhk',24,curdate())", connection)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1594             else:
# -> 1595                 cur.execute(*args)
#    1596             return cur
#
# ~\Anaconda3\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     568         try:
# --> 569             self._handle_result(self._connection.cmd_query(stmt))
#     570         except errors.InterfaceError:
#
# ~\Anaconda3\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     597             query = query.encode('utf-8')
# --> 598         result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     599
#
# ~\Anaconda3\lib\site-packages\mysql\connector\connection.py in _handle_result(self, packet)
#     485         elif packet[4] == 255:
# --> 486             raise errors.get_exception(packet)
#     487
#
# DatabaseError: 1366 (HY000): Incorrect integer value: 'maths' for column 'subject' at row 1
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-29-3560cd4ba8aa> in <module>()
# ----> 1 pd.read_sql_query("INSERT INTO student values(2, 'nhk2',25,98,'maths')", connection)
#       2 #pd.read_sql_query("INSERT INTO student values(1,'nhk',24,curdate())", connection)
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# --> 332         chunksize=chunksize,
#     333     )
#     334
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1643
#    1644         args = _convert_params(sql, params)
# -> 1645         cursor = self.execute(*args)
#    1646         columns = [col_desc[0] for col_desc in cursor.description]
#    1647
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1608                 "Execution failed on sql '{sql}': {exc}".format(sql=args[0], exc=exc)
#    1609             )
# -> 1610             raise_with_traceback(ex)
#    1611
#    1612     @staticmethod
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\compat\__init__.py in raise_with_traceback(exc, traceback)
#      45     if traceback == Ellipsis:
#      46         _, _, traceback = sys.exc_info()
# ---> 47     raise exc.with_traceback(traceback)
#      48
#      49
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1593                 cur.execute(*args, **kwargs)
#    1594             else:
# -> 1595                 cur.execute(*args)
#    1596             return cur
#    1597         except Exception as exc:
#
# ~\Anaconda3\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     567
#     568         try:
# --> 569             self._handle_result(self._connection.cmd_query(stmt))
#     570         except errors.InterfaceError:
#     571             if self._connection._have_next_result:  # pylint: disable=W0212
#
# ~\Anaconda3\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     596         if not isinstance(query, bytes):
#     597             query = query.encode('utf-8')
# --> 598         result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     599
#     600         if self._have_next_result:
#
# ~\Anaconda3\lib\site-packages\mysql\connector\connection.py in _handle_result(self, packet)
#     484             return self._handle_eof(packet)
#     485         elif packet[4] == 255:
# --> 486             raise errors.get_exception(packet)
#     487
#     488         # We have a text result set
#
# DatabaseError: Execution failed on sql 'INSERT INTO student values(2, 'nhk2',25,98,'maths')': 1366 (HY000): Incorrect integer value: 'maths' for column 'subject' at row 1

# %%
pd.read_sql_query("SELECT * FROM student", connection)
# Out:
# Empty DataFrame
# Columns: [sno, sname, age, marks, subject]
# Index: []

# %%
pd.read_sql_query("ALTER TABLE student MODIFY subject varchar(100)", connection)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-49557fe9d1a4> in <module>()
# ----> 1 pd.read_sql_query("ALTER TABLE student MODIFY subject varchar(100)", connection)
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# --> 332         chunksize=chunksize,
#     333     )
#     334
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1644         args = _convert_params(sql, params)
#    1645         cursor = self.execute(*args)
# -> 1646         columns = [col_desc[0] for col_desc in cursor.description]
#    1647
#    1648         if chunksize is not None:
#
# TypeError: 'NoneType' object is not iterable

# %%
pd.read_sql_query("SELECT * FROM student", connection)
# Out:
# Empty DataFrame
# Columns: [sno, sname, age, marks, subject]
# Index: []

# %%
pd.read_sql_query("INSERT INTO student values(2, 'nhk2',25,98,'maths')", connection)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-08739b009277> in <module>()
# ----> 1 pd.read_sql_query("INSERT INTO student values(2, 'nhk2',25,98,'maths')", connection)
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# --> 332         chunksize=chunksize,
#     333     )
#     334
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1644         args = _convert_params(sql, params)
#    1645         cursor = self.execute(*args)
# -> 1646         columns = [col_desc[0] for col_desc in cursor.description]
#    1647
#    1648         if chunksize is not None:
#
# TypeError: 'NoneType' object is not iterable

# %%
pd.read_sql_query("SELECT * FROM student", connection)
# Out:
#    sno sname  age  marks subject
# 0    2  nhk2   25     98   maths

# %%
pd.read_sql_query("INSERT INTO student values(3, 'nhk3',23,60,'travel')", connection)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-ddc14dd9c95b> in <module>()
# ----> 1 pd.read_sql_query("INSERT INTO student values(3, 'nhk3',23,60,'travel')", connection)
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# --> 332         chunksize=chunksize,
#     333     )
#     334
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1644         args = _convert_params(sql, params)
#    1645         cursor = self.execute(*args)
# -> 1646         columns = [col_desc[0] for col_desc in cursor.description]
#    1647
#    1648         if chunksize is not None:
#
# TypeError: 'NoneType' object is not iterable

# %%
pd.read_sql_query("SELECT * FROM student", connection)
# Out:
#    sno sname  age  marks subject
# 0    2  nhk2   25     98   maths
# 1    3  nhk3   23     60  travel

# %%
pd.read_sql_query("ALTER TABLE student MODIFY subject varchar(100) NOT NULL DEFAULT 'history'", connection)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-464db971d9ec> in <module>()
# ----> 1 pd.read_sql_query("ALTER TABLE student MODIFY subject varchar(100) NOT NULL DEFAULT 'history'", connection)
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# --> 332         chunksize=chunksize,
#     333     )
#     334
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1644         args = _convert_params(sql, params)
#    1645         cursor = self.execute(*args)
# -> 1646         columns = [col_desc[0] for col_desc in cursor.description]
#    1647
#    1648         if chunksize is not None:
#
# TypeError: 'NoneType' object is not iterable

# %%
pd.read_sql_query("DESC student", connection)
# Out:
#      Field          Type Null Key  Default Extra
# 0      sno       int(11)  YES         None
# 1    sname   varchar(20)  YES         None
# 2      age       int(11)  YES         None
# 3    marks       int(11)  YES         None
# 4  subject  varchar(100)   NO      history

# %%
pd.read_sql_query("ALTER TABLE student ALTER subject SET DEFAULT 'thermodynamics'", connection)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-fe60d3ff4ea4> in <module>()
# ----> 1 pd.read_sql_query("ALTER TABLE student ALTER subject SET DEFAULT 'thermodynamics'", connection)
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# --> 332         chunksize=chunksize,
#     333     )
#     334
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1644         args = _convert_params(sql, params)
#    1645         cursor = self.execute(*args)
# -> 1646         columns = [col_desc[0] for col_desc in cursor.description]
#    1647
#    1648         if chunksize is not None:
#
# TypeError: 'NoneType' object is not iterable

# %%
pd.read_sql_query("DESC student", connection)
# Out:
#      Field          Type Null Key         Default Extra
# 0      sno       int(11)  YES                None
# 1    sname   varchar(20)  YES                None
# 2      age       int(11)  YES                None
# 3    marks       int(11)  YES                None
# 4  subject  varchar(100)   NO      thermodynamics

# %%
pd.read_sql_query("ALTER TABLE student RENAME to estudent", connection)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1594             else:
# -> 1595                 cur.execute(*args)
#    1596             return cur
#
# ~\Anaconda3\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     568         try:
# --> 569             self._handle_result(self._connection.cmd_query(stmt))
#     570         except errors.InterfaceError:
#
# ~\Anaconda3\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     597             query = query.encode('utf-8')
# --> 598         result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     599
#
# ~\Anaconda3\lib\site-packages\mysql\connector\connection.py in _handle_result(self, packet)
#     485         elif packet[4] == 255:
# --> 486             raise errors.get_exception(packet)
#     487
#
# ProgrammingError: 1050 (42S01): Table 'estudent' already exists
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-41-aaf9b7081a1a> in <module>()
# ----> 1 pd.read_sql_query("ALTER TABLE student RENAME to estudent", connection)
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# --> 332         chunksize=chunksize,
#     333     )
#     334
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1643
#    1644         args = _convert_params(sql, params)
# -> 1645         cursor = self.execute(*args)
#    1646         columns = [col_desc[0] for col_desc in cursor.description]
#    1647
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1608                 "Execution failed on sql '{sql}': {exc}".format(sql=args[0], exc=exc)
#    1609             )
# -> 1610             raise_with_traceback(ex)
#    1611
#    1612     @staticmethod
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\compat\__init__.py in raise_with_traceback(exc, traceback)
#      45     if traceback == Ellipsis:
#      46         _, _, traceback = sys.exc_info()
# ---> 47     raise exc.with_traceback(traceback)
#      48
#      49
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1593                 cur.execute(*args, **kwargs)
#    1594             else:
# -> 1595                 cur.execute(*args)
#    1596             return cur
#    1597         except Exception as exc:
#
# ~\Anaconda3\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     567
#     568         try:
# --> 569             self._handle_result(self._connection.cmd_query(stmt))
#     570         except errors.InterfaceError:
#     571             if self._connection._have_next_result:  # pylint: disable=W0212
#
# ~\Anaconda3\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     596         if not isinstance(query, bytes):
#     597             query = query.encode('utf-8')
# --> 598         result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     599
#     600         if self._have_next_result:
#
# ~\Anaconda3\lib\site-packages\mysql\connector\connection.py in _handle_result(self, packet)
#     484             return self._handle_eof(packet)
#     485         elif packet[4] == 255:
# --> 486             raise errors.get_exception(packet)
#     487
#     488         # We have a text result set
#
# DatabaseError: Execution failed on sql 'ALTER TABLE student RENAME to estudent': 1050 (42S01): Table 'estudent' already exists

# %%
pd.read_sql_query("DESC estudent", connection)
# Out:
#      Field          Type Null Key         Default Extra
# 0      sno       int(11)  YES                None
# 1    sname   varchar(20)  YES                None
# 2      age       int(11)  YES                None
# 3    marks       int(11)  YES                None
# 4  subject  varchar(100)   NO      thermodynamics

# %%
pd.read_sql_query("SHOW TABLES FROM imdb", connection)
#estudent table is in row index 3
# Out:
#      Tables_in_imdb
# 0            actors
# 1         directors
# 2  directors_genres
# 3          estudent
# 4        helloworld
# 5            movies
# 6  movies_directors
# 7     movies_genres
# 8             roles
# 9           student

# %%
#pd.read_sql_query("DELETE FROM estudent", connection)
#this command deletes all the data from estudent table

# %%
#TRUNCATE table student. This is a DDL command, this can't be reverted back. all the space for student is removed
#delete is DML command

# %%
#difference between truncate, delete and drop
#drop means whole table is dropeed
#truncate means table structure still remains

# %%
pd.read_sql_query("SHOW databases", connection)
# Out:
#              Database
# 0                 db1
# 1                 db2
# 2                imdb
# 3  information_schema
# 4               mysql
# 5         mysqljigsaw
# 6  performance_schema
# 7              sakila
# 8                 sys
# 9               world

# %%
pd.read_sql_query("USE imdb", connection)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-65699d62ea37> in <module>()
# ----> 1 pd.read_sql_query("USE imdb", connection)
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# --> 332         chunksize=chunksize,
#     333     )
#     334
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1644         args = _convert_params(sql, params)
#    1645         cursor = self.execute(*args)
# -> 1646         columns = [col_desc[0] for col_desc in cursor.description]
#    1647
#    1648         if chunksize is not None:
#
# TypeError: 'NoneType' object is not iterable

# %%
pd.read_sql_query("SHOW TABLES FROM imdb", connection)
# Out:
#      Tables_in_imdb
# 0            actors
# 1         directors
# 2  directors_genres
# 3          estudent
# 4        helloworld
# 5            movies
# 6  movies_directors
# 7     movies_genres
# 8             roles
# 9           student

# %%
pd.read_sql_query("SELECT * FROM actors", connection)
# Out:
#             id     first_name           last_name gender
# 0            2        Michael  'babeepower' Viera      M
# 1            3           Eloy         'Chincheta'      M
# 2            4       Dieguito         'El Cigala'      M
# 3            5        Antonio    'El de Chipiona'      M
# 4            6           José        'El Francés'      M
# ...        ...            ...                 ...    ...
# 817713  845461         Herdís      Þorvaldsdóttir      F
# 817714  845462  Katla Margrét      Þorvaldsdóttir      F
# 817715  845463     Lilja Nótt      Þórarinsdóttir      F
# 817716  845464     Hólmfríður      Þórhallsdóttir      F
# 817717  845465       Theódóra        Þórðardóttir      F
#
# [817718 rows x 4 columns]

# %%
pd.read_sql_query("SELECT * FROM roles", connection)
# Out:
#          actor_id  movie_id              role
# 0               2    280088            Stevie
# 1               2    396232  Various/lyricist
# 2               3    376687          Gitano 1
# 3               4    336265         El Cigala
# 4               5    135644           Himself
# ...           ...       ...               ...
# 3431961    845461    137097              Kata
# 3431962    845462    208838             Magga
# 3431963    845463       870             Gunna
# 3431964    845464    378123            Gudrun
# 3431965    845465    378123
#
# [3431966 rows x 3 columns]

# %%
#clauses in sql
#IN means exact match
#BETWEEN means range matching
#LIKE means for pattern matching

# %%
pd.read_sql_query("SELECT first_name, gender from actors WHERE first_name='Michael'", connection)
# Out:
#      first_name gender
# 0       Michael      M
# 1       Michael      M
# 2       Michael      M
# 3       Michael      M
# 4       Michaël      M
# ...         ...    ...
# 4017    Michael      F
# 4018    Michael      F
# 4019    Michael      F
# 4020    Michael      F
# 4021    Michael      F
#
# [4022 rows x 2 columns]

# %%
pd.read_sql_query("SELECT actor_id, movie_id, role from roles WHERE role='kata' OR role='Magga' or role='Gunna'", connection)
# Out:
#     actor_id  movie_id   role
# 0     144881    187263   Kata
# 1     236085    153379  Gunna
# 2     478440    113126   Kata
# 3     562435    183998  Magga
# 4     568608     39052   Kata
# 5     621666    322005   Kata
# 6     626800     43114   Kata
# 7     630794    314759  Magga
# 8     630968    390721   Kata
# 9     632393    192778   Kata
# 10    642326    182526   Káta
# 11    642996    174103  Magga
# 12    644989    322099   Kata
# 13    655692    182525   Káta
# 14    659510    134635   Kata
# 15    679516    259421  Gunna
# 16    707165    222441   Kata
# 17    713183    154294  Gunna
# 18    729866    177120   Kata
# 19    732634    343707   Kata
# 20    746599    357793   Kata
# 21    755964    175635   Kata
# 22    768405    156566   Kata
# 23    777676    211038   Kata
# 24    808184    226001   Kata
# 25    812991    378049  Magga
# 26    818709    171598   Kata
# 27    826552    268266   Káta
# 28    827628    270714   Kata
# 29    827728    409099   Kata
# 30    845461    137097   Kata
# 31    845462    208838  Magga
# 32    845463       870  Gunna

# %%
pd.read_sql_query("SELECT actor_id, movie_id, role from roles WHERE role in ('kata', 'Magga', 'Gunna')", connection)
# Out:
#     actor_id  movie_id   role
# 0     144881    187263   Kata
# 1     236085    153379  Gunna
# 2     478440    113126   Kata
# 3     562435    183998  Magga
# 4     568608     39052   Kata
# 5     621666    322005   Kata
# 6     626800     43114   Kata
# 7     630794    314759  Magga
# 8     630968    390721   Kata
# 9     632393    192778   Kata
# 10    642326    182526   Káta
# 11    642996    174103  Magga
# 12    644989    322099   Kata
# 13    655692    182525   Káta
# 14    659510    134635   Kata
# 15    679516    259421  Gunna
# 16    707165    222441   Kata
# 17    713183    154294  Gunna
# 18    729866    177120   Kata
# 19    732634    343707   Kata
# 20    746599    357793   Kata
# 21    755964    175635   Kata
# 22    768405    156566   Kata
# 23    777676    211038   Kata
# 24    808184    226001   Kata
# 25    812991    378049  Magga
# 26    818709    171598   Kata
# 27    826552    268266   Káta
# 28    827628    270714   Kata
# 29    827728    409099   Kata
# 30    845461    137097   Kata
# 31    845462    208838  Magga
# 32    845463       870  Gunna

# %%
pd.read_sql_query("SELECT actor_id, movie_id, role from roles WHERE role in ('kata', 'Magga', 'Gunna') AND movie_id=270714", connection)
# Out:
#    actor_id  movie_id  role
# 0    827628    270714  Kata
